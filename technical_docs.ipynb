# %% [markdown]
# <a href="https://colab.research.google.com/github/raduncan313/test/blob/main/technical_docs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ingest

# %%
def hello():
  return 'hi'
hello()
# Out:
# 'hi'

# %% [markdown]
# ## EDA

# %% [markdown]
# ## Modeling

# %% [markdown]
# ## Conclusion

# %% [markdown]
# This is a change
